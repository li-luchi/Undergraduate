# %%
from matplotlib import pyplot as plt
import pandas as pd
import numpy as np

data = pd.read_excel(io = 'totalFeaturesPro.xls', header=None)
nrow = len(data)
ncol = len(data.columns)
row_list = []
col_list = []
for i in range(ncol):
    col = data.iloc[:, i]
    col_list.append(col.values)
col_list = np.array(col_list)
lable = col_list[79, :]
X = col_list[:79, :]

# %%
from minepy import MINE

mine = MINE(alpha = 0.6, c = 15)
for i in X:
    mine.compute_score(i, lable)
    print(mine.mic())
# Out:
# 0.22181405854760677
# 0.12599290651098452
# 0.12599290651098452
# 0.10561185855806528
# 0.19244446937305654
# 0.15863136108737372
# 0.10561185855806528
# 0.15354996241139177
# 0.28180610812238993
# 0.11969870280677473
# 0.13482518676579042
# 0.16241245564219334
# 0.15948041726985107
# 0.1886327035515695
# 0.1356748833572432
# 0.17705444802091716
# 0.10561185855806528
# 0.16923969094914287
# 0.1822368541257096
# 0.0
# 0.26004112664476536
# 0.1624124556421935
# 0.30787803865248753
# 0.2818061081223901
# 0.22114661968310115
# 0.2584068831703824
# 0.1025424691089611
# 0.1356748833572432
# 0.17313157489906525
# 0.10215185436609309
# 0.1886327035515695
# 0.18233906476889772
# 0.2343111015347415
# 0.239640196854
# 0.10215185436609309
# 0.22039575495219874
# 0.26004112664476536
# 0.21388729830502176
# 0.13032992539175142
# 0.10215185436609309
# 0.35475502171599305
# 0.14230935907210596
# 0.1356748833572432
# 0.13234787673219445
# 0.25734787673219445
# 0.34533473019430955
# 0.09204063947755713
# 0.22042573421828218
# 0.1722220895489999
# 0.1413512272375424
# 0.15837567909299158
# 0.18975357166362616
# 0.023728945827193027
# 0.24496630200445985
# 0.1717761466977864
# 0.2646734054406235
# 0.2461347211169645
# 0.14375749194029366
# 0.09299848374843943
# 0.08612628631993446
# 0.12565584609875716
# 0.22684451305300105
# 0.12599290651098452
# 0.17748968939338738
# 0.08612628631993446
# 0.1290998435556993
# 0.17226084247512333
# 0.19346050490650266
# 0.26756745017737543
# 0.21059247315589394
# 0.17313157489906542
# 0.19346050490650266
# 0.15837567909299158
# 0.10599929610320716
# 0.06758991901467515
# 0.21845808162600902
# 0.16281074119819305
# 0.13567488335724304
# 0.21292916647045823
